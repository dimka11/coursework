# %%
import os
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_o = pd.read_csv('29634.13.02.2009.08.05.2021.1.0.0.ru.utf8.00000000.csv', skiprows=6, sep=';', index_col=0)

def inp_prep(df_o, col_drop_list=['P','Pa','ff3' , 'ff10', 'tR', 'E', 'Tg', 'E', 'sss', "E'", 'W1', 'W2', 'Unnamed: 29'], info=True, reverse=True):
    #clean cols
    dfa = df_o.drop(columns=col_drop_list)
    
    # replace NaN to mean of 2 nb
    dfa['T'] = dfa['T'].where(dfa['T'].values == 999, other=(dfa['T'].fillna(method='ffill') + dfa['T'].fillna(method='bfill'))/2)
    # datetimeindex
    dfa.index = pd.to_datetime(dfa.index, dayfirst=True)
    if info is True:
         dfa.info()
    if reverse is True:
        # reverse
        dfa = dfa.iloc[::-1]
   
    return dfa
dfa = inp_prep(df_o)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15396 entries, 2021-05-08 19:00:00 to 2009-02-13 19:00:00
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       15396 non-null  float64
#  1   Po      15376 non-null  float64
#  2   U       15382 non-null  float64
#  3   DD      15251 non-null  object
#  4   Ff      15384 non-null  float64
#  5   N       15381 non-null  object
#  6   WW      15396 non-null  object
#  7   Tn      2457 non-null   float64
#  8   Tx      1935 non-null   float64
#  9   Cl      1650 non-null   object
#  10  Nh      2533 non-null   object
#  11  H       2539 non-null   object
#  12  Cm      1240 non-null   object
#  13  Ch      2154 non-null   object
#  14  VV      15391 non-null  float64
#  15  Td      2981 non-null   float64
#  16  RRR     3202 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 2.1+ MB

# %%
dfa.loc['2021-05'].tail(8)
# Out:
#                                  T     Po     U  \
# Местное время в Новосибирске
# 2021-05-07 22:00:00           14.7  749.0  32.0
# 2021-05-08 01:00:00           11.9  751.0  38.0
# 2021-05-08 04:00:00            8.3  752.0  53.0
# 2021-05-08 07:00:00            7.8  753.0  52.0
# 2021-05-08 10:00:00           15.9  752.0  27.0
# 2021-05-08 13:00:00           19.5  751.0  26.0
# 2021-05-08 16:00:00           20.1  751.0  25.0
# 2021-05-08 19:00:00           21.1  750.0  24.0
#
#                                                          DD   Ff  \
# Местное время в Новосибирске
# 2021-05-07 22:00:00                        Штиль, безветрие  0.0
# 2021-05-08 01:00:00           Ветер, дующий с северо-запада  1.0
# 2021-05-08 04:00:00                        Штиль, безветрие  0.0
# 2021-05-08 07:00:00                  Ветер, дующий с запада  1.0
# 2021-05-08 10:00:00                  Ветер, дующий с запада  1.0
# 2021-05-08 13:00:00           Ветер, дующий с северо-запада  4.0
# 2021-05-08 16:00:00           Ветер, дующий с северо-запада  4.0
# 2021-05-08 19:00:00           Ветер, дующий с северо-запада  3.0
#
#                                                       N  \
# Местное время в Новосибирске
# 2021-05-07 22:00:00                           70 – 80%.
# 2021-05-08 01:00:00                                60%.
# 2021-05-08 04:00:00                           70 – 80%.
# 2021-05-08 07:00:00                        Облаков нет.
# 2021-05-08 10:00:00                        Облаков нет.
# 2021-05-08 13:00:00                                60%.
# 2021-05-08 16:00:00           90  или более, но не 100%
# 2021-05-08 19:00:00                           70 – 80%.
#
#                                                                              WW  \
# Местное время в Новосибирске
# 2021-05-07 22:00:00           Видимость ухудшена дымом, например: от степных...
# 2021-05-08 01:00:00           Видимость ухудшена дымом, например: от степных...
# 2021-05-08 04:00:00           Видимость ухудшена дымом, например: от степных...
# 2021-05-08 07:00:00           Видимость ухудшена дымом, например: от степных...
# 2021-05-08 10:00:00           Видимость ухудшена дымом, например: от степных...
# 2021-05-08 13:00:00
# 2021-05-08 16:00:00
# 2021-05-08 19:00:00           Видимость ухудшена дымом, например: от степных...
#
#                                Tn    Tx   Cl   Nh    H   Cm   Ch    VV  Td  \
# Местное время в Новосибирске
# 2021-05-07 22:00:00           NaN   NaN  NaN  NaN  NaN  NaN  NaN   4.0 NaN
# 2021-05-08 01:00:00           NaN   NaN  NaN  NaN  NaN  NaN  NaN   4.0 NaN
# 2021-05-08 04:00:00           NaN   NaN  NaN  NaN  NaN  NaN  NaN   4.0 NaN
# 2021-05-08 07:00:00           6.1   NaN  NaN  NaN  NaN  NaN  NaN   4.0 NaN
# 2021-05-08 10:00:00           NaN   NaN  NaN  NaN  NaN  NaN  NaN   4.0 NaN
# 2021-05-08 13:00:00           NaN   NaN  NaN  NaN  NaN  NaN  NaN  10.0 NaN
# 2021-05-08 16:00:00           NaN   NaN  NaN  NaN  NaN  NaN  NaN  10.0 NaN
# 2021-05-08 19:00:00           NaN  21.2  NaN  NaN  NaN  NaN  NaN   4.0 NaN
#
#                                       RRR
# Местное время в Новосибирске
# 2021-05-07 22:00:00                   NaN
# 2021-05-08 01:00:00                   NaN
# 2021-05-08 04:00:00                   NaN
# 2021-05-08 07:00:00           Осадков нет
# 2021-05-08 10:00:00                   NaN
# 2021-05-08 13:00:00                   NaN
# 2021-05-08 16:00:00                   NaN
# 2021-05-08 19:00:00           Осадков нет

# %%
# Nh # H # Cm # Ch # Td
dfa[~dfa['Td'].isnull()]['H'].tail(5)
# Out:
# Местное время в Новосибирске
# 2011-04-28 07:00:00                           1000-1500
# 2011-04-30 10:00:00    2500 или более, или облаков нет.
# 2011-04-30 13:00:00    2500 или более, или облаков нет.
# 2011-04-30 16:00:00    2500 или более, или облаков нет.
# 2011-04-30 19:00:00    2500 или более, или облаков нет.
# Name: H, dtype: object

# %%
dfa['DD'].unique()
# Out:
# array(['Ветер, дующий с востоко-юго-востока', 'Ветер, дующий с востока',
#        'Ветер, дующий с севера', 'Ветер, дующий с юго-юго-запада',
#        'Ветер, дующий с юго-запада', 'Штиль, безветрие',
#        'Ветер, дующий с северо-северо-запада',
#        'Ветер, дующий с северо-запада',
#        'Ветер, дующий с северо-северо-востока',
#        'Ветер, дующий с северо-востока', 'Ветер, дующий с юга',
#        'Ветер, дующий с западо-юго-запада',
#        'Ветер, дующий с юго-юго-востока', 'Ветер, дующий с запада',
#        'Ветер, дующий с западо-северо-запада',
#        'Ветер, дующий с востоко-северо-востока',
#        'Ветер, дующий с юго-востока', nan], dtype=object)

# %%
dfa['DD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='DD'>

# %%
dfa['DD'].value_counts()
# Out:
# Ветер, дующий с юго-запада                3649
# Штиль, безветрие                          2059
# Ветер, дующий с запада                    1980
# Ветер, дующий с востока                   1889
# Ветер, дующий с северо-запада             1502
# Ветер, дующий с юга                       1261
# Ветер, дующий с юго-востока                716
# Ветер, дующий с северо-востока             564
# Ветер, дующий с юго-юго-запада             446
# Ветер, дующий с севера                     417
# Ветер, дующий с западо-юго-запада          215
# Ветер, дующий с северо-северо-востока      132
# Ветер, дующий с северо-северо-запада       129
# Ветер, дующий с западо-северо-запада       106
# Ветер, дующий с юго-юго-востока            102
# Ветер, дующий с востоко-юго-востока         56
# Ветер, дующий с востоко-северо-востока      28
# Name: DD, dtype: int64

# %%
# Winter period
dfa.loc['2020-11-01':'2021-03-01']['DD'].value_counts()
# Out:
# Ветер, дующий с юго-запада        319
# Штиль, безветрие                  217
# Ветер, дующий с запада            125
# Ветер, дующий с востока           103
# Ветер, дующий с северо-запада      60
# Ветер, дующий с юга                59
# Ветер, дующий с юго-востока        28
# Ветер, дующий с северо-востока     20
# Ветер, дующий с севера              5
# Name: DD, dtype: int64

# %%
dfa['Ff'][dfa['Ff'] <= 50].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
dfa['N'].value_counts()
# Out:
# 100%.                                                                 6775
# Облаков нет.                                                          2573
# 70 – 80%.                                                             2070
# 60%.                                                                  1202
# 90  или более, но не 100%                                              949
# 20–30%.                                                                870
# 40%.                                                                   765
# 10%  или менее, но не 0                                                112
# 50%.                                                                    58
# Небо не видно из-за тумана и/или других метеорологических явлений.       7
# Name: N, dtype: int64

# %%
# Winter period
dfa.loc['2020-11-01':'2021-03-01']['N'].value_counts()
# Out:
# 100%.                        550
# Облаков нет.                 161
# 70 – 80%.                     75
# 90  или более, но не 100%     47
# 60%.                          39
# 40%.                          31
# 20–30%.                       27
# 10%  или менее, но не 0        3
# Name: N, dtype: int64

# %% [markdown]
# ### function for convert category data

# %%
def conv_wind(dfa):
    m_df4_ = dfa['DD'].replace(['Ветер, дующий с запада', 'Ветер, дующий с юго-запада', 'Ветер, дующий с западо-юго-запада', 'Ветер, дующий с западо-северо-запада'],'West')
    m_df4_ = m_df4_.replace(['Ветер, дующий с севера', 'Ветер, дующий с северо-запада', 'Ветер, дующий с северо-северо-востока', 'Ветер, дующий с северо-северо-запада'],'North')
    m_df4_ = m_df4_.replace(['Ветер, дующий с востока', 'Ветер, дующий с северо-востока', 'Ветер, дующий с востоко-юго-востока', 'Ветер, дующий с востоко-северо-востока'],'East')
    m_df4_ = m_df4_.replace(['Ветер, дующий с юга', 'Ветер, дующий с юго-востока', 'Ветер, дующий с юго-юго-запада', 'Ветер, дующий с юго-юго-востока'],'South')
    m_df4_ = m_df4_.replace(['Штиль, безветрие'],'Calm')
    m_df4 = dfa.copy()
    m_df4['DD'] = m_df4_
    m_df4['DD'].unique()
    return m_df4
m_df4 = conv_wind(dfa)

# %%
# clouds values to float type
def conv_cloud(dfa):
    m_df4_ = dfa['N'].replace(['70 – 80%.'],75)
    m_df4_ = m_df4_.replace(['90  или более, но не 100%'],90)
    m_df4_ = m_df4_.replace(['60%.'],60)
    m_df4_ = m_df4_.replace(['100%.'], 100)
    m_df4_ = m_df4_.replace(['Облаков нет.'],0)
    m_df4_ = m_df4_.replace(['40%.'],40)
    m_df4_ = m_df4_.replace(['20–30%.'],25)
    m_df4_ = m_df4_.replace(['10%  или менее, но не 0'],10)
    m_df4_ = m_df4_.replace(['50%.'],50)
    m_df4_ = m_df4_.replace(['Небо не видно из-за тумана и/или других метеорологических явлений.'],101)
    m_df4 = dfa.copy()
    m_df4['N'] = m_df4_
    m_df4['N'].unique()
    return m_df4

# %%
#precip values to float type
def conv_precip(dfa):
    m_df4_ = dfa['RRR'].replace(['Осадков нет'],0)
    m_df4_ = m_df4_.replace(['Следы осадков'],0.1)
    m_df4_ = m_df4_.astype(float)
    m_df4 = dfa.copy()
    m_df4['RRR'] = m_df4_
    return m_df4

# %%
#conv_wind_label
def conv_wind_label(dfa):
    m_df4_ = dfa['DD'].replace(['West'],1)
    m_df4_ = m_df4_.replace(['North'],2)
    m_df4_ = m_df4_.replace(['East'],3)
    m_df4_ = m_df4_.replace(['South'],4)
    m_df4_ = m_df4_.replace(['Calm'],0)
    m_df4 = dfa.copy()
    m_df4['DD'] = m_df4_
    m_df4['DD'].unique()
    return m_df4

# %%
m_df4['DD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='DD'>

# %%
# Winter period
m_df4.loc['2020-11-01':'2021-03-01']['DD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='DD'>

# %%
# Тюмень
df_t = pd.read_csv('28367.01.02.2005.13.05.2021.1.0.0.ru.utf8.00000000.csv', skiprows=6, sep=';', index_col=0)

df_t = inp_prep(df_t, ['ff3', 'ff10', 'E', 'Tg', 'E', "E'", 'W1', 'W2', 'Unnamed: 29'])
# Out:
# C:\Users\Dima\AppData\Roaming\Python\Python36\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (21,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 47387 entries, 2021-05-13 11:00:00 to 2005-02-01 05:00:00
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       47387 non-null  float64
#  1   Po      47201 non-null  float64
#  2   P       47238 non-null  float64
#  3   Pa      24195 non-null  float64
#  4   U       47299 non-null  float64
#  5   DD      47370 non-null  object
#  6   Ff      47370 non-null  float64
#  7   N       47306 non-null  object
#  8   WW      47387 non-null  object
#  9   Tn      6417 non-null   float64
#  10  Tx      8682 non-null   float64
#  11  Cl      29553 non-null  object
#  12  Nh      38958 non-null  object
#  13  H       39022 non-null  object
#  14  Cm      28933 non-null  object
#  15  Ch      25800 non-null  object
#  16  VV      47298 non-null  object
#  17  Td      47325 non-null  float64
#  18  RRR     10918 non-null  object
#  19  tR      10918 non-null  float64
#  20  sss     2637 non-null   object
# dtypes: float64(10), object(11)
# memory usage: 8.0+ MB

# %%
df_t.loc['2021-01'].tail(8)
# Out:
#                            T     Po      P   Pa     U  \
# Местное время в Тюмени
# 2021-01-31 02:00:00     -6.8  753.8  763.6 -0.3  81.0
# 2021-01-31 05:00:00     -7.7  754.0  763.9  0.2  84.0
# 2021-01-31 08:00:00     -9.9  754.3  764.3  0.3  90.0
# 2021-01-31 11:00:00     -8.6  755.8  765.7  1.5  86.0
# 2021-01-31 14:00:00     -7.2  756.6  766.5  0.8  76.0
# 2021-01-31 17:00:00     -8.7  757.7  767.7  1.1  80.0
# 2021-01-31 20:00:00    -13.7  758.2  768.4  0.5  89.0
# 2021-01-31 23:00:00    -15.1  757.8  768.0 -0.4  87.0
#
#                                                        DD   Ff  \
# Местное время в Тюмени
# 2021-01-31 02:00:00       Ветер, дующий с юго-юго-востока  1.0
# 2021-01-31 05:00:00                   Ветер, дующий с юга  1.0
# 2021-01-31 08:00:00                   Ветер, дующий с юга  1.0
# 2021-01-31 11:00:00     Ветер, дующий с западо-юго-запада  2.0
# 2021-01-31 14:00:00     Ветер, дующий с западо-юго-запада  2.0
# 2021-01-31 17:00:00                Ветер, дующий с запада  1.0
# 2021-01-31 20:00:00                      Штиль, безветрие  0.0
# 2021-01-31 23:00:00               Ветер, дующий с востока  1.0
#
#                                                 N  \
# Местное время в Тюмени
# 2021-01-31 02:00:00                         100%.
# 2021-01-31 05:00:00     90  или более, но не 100%
# 2021-01-31 08:00:00                          40%.
# 2021-01-31 11:00:00                         100%.
# 2021-01-31 14:00:00                     70 – 80%.
# 2021-01-31 17:00:00                          60%.
# 2021-01-31 20:00:00                          40%.
# 2021-01-31 23:00:00                       20–30%.
#
#                                                                        WW  \
# Местное время в Тюмени
# 2021-01-31 02:00:00
# 2021-01-31 05:00:00
# 2021-01-31 08:00:00     Облака в целом рассеиваются или становятся мен...
# 2021-01-31 11:00:00       Облака в целом образовывались или развивались.
# 2021-01-31 14:00:00                Состояние неба в общем не изменилось.
# 2021-01-31 17:00:00                Состояние неба в общем не изменилось.
# 2021-01-31 20:00:00
# 2021-01-31 23:00:00
#
#                           Tn  ...  \
# Местное время в Тюмени        ...
# 2021-01-31 02:00:00      NaN  ...
# 2021-01-31 05:00:00      NaN  ...
# 2021-01-31 08:00:00     -9.9  ...
# 2021-01-31 11:00:00    -10.4  ...
# 2021-01-31 14:00:00      NaN  ...
# 2021-01-31 17:00:00      NaN  ...
# 2021-01-31 20:00:00      NaN  ...
# 2021-01-31 23:00:00      NaN  ...
#
#                                                                        Cl  \
# Местное время в Тюмени
# 2021-01-31 02:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-01-31 05:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-01-31 08:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-01-31 11:00:00     Слоистые разорванные или кучевые разорванные о...
# 2021-01-31 14:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-01-31 17:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-01-31 20:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-01-31 23:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
#
#                                   Nh                                 H  \
# Местное время в Тюмени
# 2021-01-31 02:00:00            100%.  2500 или более, или облаков нет.
# 2021-01-31 05:00:00        70 – 80%.  2500 или более, или облаков нет.
# 2021-01-31 08:00:00          20–30%.  2500 или более, или облаков нет.
# 2021-01-31 11:00:00          20–30%.                           300-600
# 2021-01-31 14:00:00             40%.  2500 или более, или облаков нет.
# 2021-01-31 17:00:00          20–30%.  2500 или более, или облаков нет.
# 2021-01-31 20:00:00     Облаков нет.  2500 или более, или облаков нет.
# 2021-01-31 23:00:00     Облаков нет.  2500 или более, или облаков нет.
#
#                                                                        Cm  \
# Местное время в Тюмени
# 2021-01-31 02:00:00     Высококучевые просвечивающие, полосами, либо о...
# 2021-01-31 05:00:00     Высококучевые просвечивающие, расположенные на...
# 2021-01-31 08:00:00     Высококучевые просвечивающие, расположенные на...
# 2021-01-31 11:00:00     Высококучевые, просвечивающие или плотные в дв...
# 2021-01-31 14:00:00     Высококучевые, просвечивающие или плотные в дв...
# 2021-01-31 17:00:00     Высокослоистые непросвечивающие или слоисто-до...
# 2021-01-31 20:00:00     Высококучевых, высокослоистых или слоисто-дожд...
# 2021-01-31 23:00:00     Высококучевых, высокослоистых или слоисто-дожд...
#
#                                                                        Ch  \
# Местное время в Тюмени
# 2021-01-31 02:00:00                                                   NaN
# 2021-01-31 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-01-31 08:00:00     Перистые плотные в виде клочьев или скрученных...
# 2021-01-31 11:00:00                                                   NaN
# 2021-01-31 14:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-01-31 17:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-01-31 20:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-01-31 23:00:00     Перистые нитевидные, иногда когтевидные, не ра...
#
#                           VV    Td            RRR    tR   sss
# Местное время в Тюмени
# 2021-01-31 02:00:00     10.0  -9.5            NaN   NaN   NaN
# 2021-01-31 05:00:00     10.0 -10.0            NaN   NaN   NaN
# 2021-01-31 08:00:00     10.0 -11.2  Следы осадков  12.0  26.0
# 2021-01-31 11:00:00     10.0 -10.6            NaN   NaN   NaN
# 2021-01-31 14:00:00     10.0 -10.7            NaN   NaN   NaN
# 2021-01-31 17:00:00     10.0 -11.6            NaN   NaN   NaN
# 2021-01-31 20:00:00     10.0 -15.2  Следы осадков  12.0   NaN
# 2021-01-31 23:00:00     10.0 -16.8            NaN   NaN   NaN
#
# [8 rows x 21 columns]

# %%
df_t4 = conv_wind(df_t)

# %%
# Wind speed distribution
df_t['Ff'][df_t['Ff'] <= 50].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df_t.loc['2021-02']['Ff'][df_t['Ff'] <= 50].astype(float).plot()
# Out:
# <AxesSubplot:xlabel='Местное время в Тюмени'>

# %%
# Wind direction distrubuton
df_t4['DD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='DD'>

# %%
# Winter period
df_t4.loc['2020-11-01':'2021-03-01']['DD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='DD'>

# %%
# Summer period
df_t4.loc['2020-05-01':'2021-10-01']['DD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='DD'>

# %%
df_t4['N'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='N'>

# %%
# Winter period
df_t4.loc['2020-11-01':'2021-03-01']['N'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='N'>

# %%
# Summer period
df_t4.loc['2020-05-01':'2021-10-01']['N'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='N'>

# %%
df_t4['N'].unique()
# Out:
# array(['70 – 80%.', '100%.', '40%.', 'Облаков нет.', '60%.', '20–30%.',
#        '10%  или менее, но не 0', '50%.', '90  или более, но не 100%',
#        'Небо не видно из-за тумана и/или других метеорологических явлений.',
#        nan], dtype=object)

# %%
df_t4 = conv_cloud(df_t4)
df_t4 = conv_wind_label(df_t4)
df_t4 = conv_precip(df_t4)
df_t4.tail(5)
# Out:
#                            T     Po      P   Pa     U   DD   Ff     N WW   Tn  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     10.1  760.2  769.4  0.1  70.0  0.0  0.0  10.0     NaN
# 2021-05-13 02:00:00      7.8  759.7  769.0 -0.5  79.0  0.0  0.0  40.0     NaN
# 2021-05-13 05:00:00      9.6  759.4  768.7 -0.3  72.0  1.0  1.0  75.0     NaN
# 2021-05-13 08:00:00     17.9  758.8  767.8 -0.6  42.0  1.0  4.0  40.0     7.3
# 2021-05-13 11:00:00     24.4  758.1  766.9 -0.7  28.0  1.0  3.0  40.0     NaN
#
#                         ...  \
# Местное время в Тюмени  ...
# 2021-05-12 23:00:00     ...
# 2021-05-13 02:00:00     ...
# 2021-05-13 05:00:00     ...
# 2021-05-13 08:00:00     ...
# 2021-05-13 11:00:00     ...
#
#                                                                        Cl  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 02:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 05:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 08:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 11:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
#
#                                              Nh  \
# Местное время в Тюмени
# 2021-05-12 23:00:00                Облаков нет.
# 2021-05-13 02:00:00                Облаков нет.
# 2021-05-13 05:00:00     10%  или менее, но не 0
# 2021-05-13 08:00:00     10%  или менее, но не 0
# 2021-05-13 11:00:00                Облаков нет.
#
#                                                        H  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     2500 или более, или облаков нет.
# 2021-05-13 02:00:00     2500 или более, или облаков нет.
# 2021-05-13 05:00:00     2500 или более, или облаков нет.
# 2021-05-13 08:00:00     2500 или более, или облаков нет.
# 2021-05-13 11:00:00     2500 или более, или облаков нет.
#
#                                                                        Cm  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     Высококучевых, высокослоистых или слоисто-дожд...
# 2021-05-13 02:00:00     Высококучевых, высокослоистых или слоисто-дожд...
# 2021-05-13 05:00:00     Высококучевые просвечивающие, расположенные на...
# 2021-05-13 08:00:00     Высококучевые просвечивающие, расположенные на...
# 2021-05-13 11:00:00     Высококучевых, высокослоистых или слоисто-дожд...
#
#                                                                        Ch  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-05-13 02:00:00     Перистые плотные в виде клочьев или скрученных...
# 2021-05-13 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-05-13 08:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-05-13 11:00:00     Перистые нитевидные, иногда когтевидные, не ра...
#
#                           VV   Td  RRR    tR  sss
# Местное время в Тюмени
# 2021-05-12 23:00:00     10.0  4.8  NaN   NaN  NaN
# 2021-05-13 02:00:00     10.0  4.4  NaN   NaN  NaN
# 2021-05-13 05:00:00     10.0  4.8  NaN   NaN  NaN
# 2021-05-13 08:00:00     10.0  4.9  0.0  12.0  NaN
# 2021-05-13 11:00:00     10.0  4.7  NaN   NaN  NaN
#
# [5 rows x 21 columns]

# %%
df_t4.corr()
# Out:
#             T        Po         P        Pa         U        DD        Ff  \
# T    1.000000 -0.421402 -0.467369 -0.079396 -0.338533 -0.033683  0.105401
# Po  -0.421402  1.000000  0.997727  0.060487 -0.088976 -0.001512 -0.234167
# P   -0.467369  0.997727  1.000000  0.061128 -0.068751  0.000327 -0.233844
# Pa  -0.079396  0.060487  0.061128  1.000000  0.081072 -0.302507 -0.041250
# U   -0.338533 -0.088976 -0.068751  0.081072  1.000000 -0.060743 -0.312446
# DD  -0.033683 -0.001512  0.000327 -0.302507 -0.060743  1.000000  0.143106
# Ff   0.105401 -0.234167 -0.233844 -0.041250 -0.312446  0.143106  1.000000
# N    0.104634 -0.283388 -0.281990 -0.119040  0.137838  0.119374  0.251282
# Tn   0.967555 -0.462821 -0.506769 -0.010844 -0.202405 -0.013344  0.182801
# Tx   0.976683 -0.419279 -0.463786 -0.033157 -0.302365 -0.073843 -0.112678
# Td   0.938103 -0.479182 -0.520553 -0.044442 -0.000989 -0.058843  0.003479
# RRR  0.135821 -0.252925 -0.253195  0.027300  0.228285 -0.031169  0.102524
# tR  -0.008124  0.006776  0.007012 -0.022540 -0.004811  0.007680 -0.012546
#
#             N        Tn        Tx        Td       RRR        tR
# T    0.104634  0.967555  0.976683  0.938103  0.135821 -0.008124
# Po  -0.283388 -0.462821 -0.419279 -0.479182 -0.252925  0.006776
# P   -0.281990 -0.506769 -0.463786 -0.520553 -0.253195  0.007012
# Pa  -0.119040 -0.010844 -0.033157 -0.044442  0.027300 -0.022540
# U    0.137838 -0.202405 -0.302365 -0.000989  0.228285 -0.004811
# DD   0.119374 -0.013344 -0.073843 -0.058843 -0.031169  0.007680
# Ff   0.251282  0.182801 -0.112678  0.003479  0.102524 -0.012546
# N    1.000000  0.145749  0.039381  0.160296  0.159549  0.000488
# Tn   0.145749  1.000000       NaN  0.966628  0.154137       NaN
# Tx   0.039381       NaN  1.000000  0.931561  0.140113 -0.006984
# Td   0.160296  0.966628  0.931561  1.000000  0.205123 -0.010001
# RRR  0.159549  0.154137  0.140113  0.205123  1.000000 -0.040612
# tR   0.000488       NaN -0.006984 -0.010001 -0.040612  1.000000

# %%
df_t4.loc['2021-03'].corr()
# Out:
#             T        Po         P        Pa         U        DD        Ff  \
# T    1.000000  0.033896  0.000386 -0.161921 -0.468922  0.068427  0.415391
# Po   0.033896  1.000000  0.999418  0.079670 -0.511077 -0.016947  0.007124
# P    0.000386  0.999418  1.000000  0.084890 -0.496233 -0.019210 -0.006784
# Pa  -0.161921  0.079670  0.084890  1.000000  0.163247 -0.430867 -0.015433
# U   -0.468922 -0.511077 -0.496233  0.163247  1.000000 -0.106651 -0.471056
# DD   0.068427 -0.016947 -0.019210 -0.430867 -0.106651  1.000000  0.049813
# Ff   0.415391  0.007124 -0.006784 -0.015433 -0.471056  0.049813  1.000000
# N    0.179532 -0.342318 -0.348453 -0.188715  0.156190  0.158619  0.184992
# Tn   0.970467 -0.112574 -0.144137 -0.001243 -0.295292  0.034447  0.354247
# Tx   0.965183  0.216776  0.190542 -0.155899 -0.457960  0.323257  0.217351
# Td   0.813564 -0.294345 -0.322130 -0.059064  0.119778  0.005971  0.165601
# RRR -0.140508 -0.374874 -0.371149  0.212346  0.400807 -0.207058 -0.065742
# tR        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             N        Tn        Tx        Td       RRR  tR
# T    0.179532  0.970467  0.965183  0.813564 -0.140508 NaN
# Po  -0.342318 -0.112574  0.216776 -0.294345 -0.374874 NaN
# P   -0.348453 -0.144137  0.190542 -0.322130 -0.371149 NaN
# Pa  -0.188715 -0.001243 -0.155899 -0.059064  0.212346 NaN
# U    0.156190 -0.295292 -0.457960  0.119778  0.400807 NaN
# DD   0.158619  0.034447  0.323257  0.005971 -0.207058 NaN
# Ff   0.184992  0.354247  0.217351  0.165601 -0.065742 NaN
# N    1.000000  0.316044 -0.014624  0.298808  0.288612 NaN
# Tn   0.316044  1.000000       NaN  0.917395  0.001619 NaN
# Tx  -0.014624       NaN  1.000000  0.689707 -0.242644 NaN
# Td   0.298808  0.917395  0.689707  1.000000  0.050177 NaN
# RRR  0.288612  0.001619 -0.242644  0.050177  1.000000 NaN
# tR        NaN       NaN       NaN       NaN       NaN NaN

# %%
df_t4.tail(5)
# Out:
#                            T     Po      P   Pa     U   DD   Ff     N WW   Tn  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     10.1  760.2  769.4  0.1  70.0  0.0  0.0  10.0     NaN
# 2021-05-13 02:00:00      7.8  759.7  769.0 -0.5  79.0  0.0  0.0  40.0     NaN
# 2021-05-13 05:00:00      9.6  759.4  768.7 -0.3  72.0  1.0  1.0  75.0     NaN
# 2021-05-13 08:00:00     17.9  758.8  767.8 -0.6  42.0  1.0  4.0  40.0     7.3
# 2021-05-13 11:00:00     24.4  758.1  766.9 -0.7  28.0  1.0  3.0  40.0     NaN
#
#                         ...  \
# Местное время в Тюмени  ...
# 2021-05-12 23:00:00     ...
# 2021-05-13 02:00:00     ...
# 2021-05-13 05:00:00     ...
# 2021-05-13 08:00:00     ...
# 2021-05-13 11:00:00     ...
#
#                                                                        Cl  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 02:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 05:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 08:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2021-05-13 11:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
#
#                                              Nh  \
# Местное время в Тюмени
# 2021-05-12 23:00:00                Облаков нет.
# 2021-05-13 02:00:00                Облаков нет.
# 2021-05-13 05:00:00     10%  или менее, но не 0
# 2021-05-13 08:00:00     10%  или менее, но не 0
# 2021-05-13 11:00:00                Облаков нет.
#
#                                                        H  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     2500 или более, или облаков нет.
# 2021-05-13 02:00:00     2500 или более, или облаков нет.
# 2021-05-13 05:00:00     2500 или более, или облаков нет.
# 2021-05-13 08:00:00     2500 или более, или облаков нет.
# 2021-05-13 11:00:00     2500 или более, или облаков нет.
#
#                                                                        Cm  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     Высококучевых, высокослоистых или слоисто-дожд...
# 2021-05-13 02:00:00     Высококучевых, высокослоистых или слоисто-дожд...
# 2021-05-13 05:00:00     Высококучевые просвечивающие, расположенные на...
# 2021-05-13 08:00:00     Высококучевые просвечивающие, расположенные на...
# 2021-05-13 11:00:00     Высококучевых, высокослоистых или слоисто-дожд...
#
#                                                                        Ch  \
# Местное время в Тюмени
# 2021-05-12 23:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-05-13 02:00:00     Перистые плотные в виде клочьев или скрученных...
# 2021-05-13 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-05-13 08:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-05-13 11:00:00     Перистые нитевидные, иногда когтевидные, не ра...
#
#                           VV   Td  RRR    tR  sss
# Местное время в Тюмени
# 2021-05-12 23:00:00     10.0  4.8  NaN   NaN  NaN
# 2021-05-13 02:00:00     10.0  4.4  NaN   NaN  NaN
# 2021-05-13 05:00:00     10.0  4.8  NaN   NaN  NaN
# 2021-05-13 08:00:00     10.0  4.9  0.0  12.0  NaN
# 2021-05-13 11:00:00     10.0  4.7  NaN   NaN  NaN
#
# [5 rows x 21 columns]

# %%
# specific date range
df_t.loc[df_t.index.hour.isin([14,17,20])].loc['2020-03':'2020-05'].tail(5)
# Out:
#                            T     Po      P   Pa     U  \
# Местное время в Тюмени
# 2020-05-30 17:00:00     24.7  751.5  760.3 -0.7  28.0
# 2020-05-30 20:00:00     21.8  750.7  759.5 -0.8  38.0
# 2020-05-31 14:00:00     15.9  749.5  758.5 -0.3  47.0
# 2020-05-31 17:00:00     15.4  749.2  758.2 -0.3  43.0
# 2020-05-31 20:00:00     11.9  748.7  757.8 -0.5  63.0
#
#                                                     DD   Ff  \
# Местное время в Тюмени
# 2020-05-30 17:00:00             Ветер, дующий с запада  3.0
# 2020-05-30 20:00:00             Ветер, дующий с запада  1.0
# 2020-05-31 14:00:00     Ветер, дующий с северо-востока  3.0
# 2020-05-31 17:00:00     Ветер, дующий с северо-востока  4.0
# 2020-05-31 20:00:00     Ветер, дующий с северо-востока  4.0
#
#                                                 N  \
# Местное время в Тюмени
# 2020-05-30 17:00:00                          40%.
# 2020-05-30 20:00:00                     70 – 80%.
# 2020-05-31 14:00:00                         100%.
# 2020-05-31 17:00:00     90  или более, но не 100%
# 2020-05-31 20:00:00                         100%.
#
#                                                             WW  Tn  ...  \
# Местное время в Тюмени                                              ...
# 2020-05-30 17:00:00                                            NaN  ...
# 2020-05-30 20:00:00                                            NaN  ...
# 2020-05-31 14:00:00                                            NaN  ...
# 2020-05-31 17:00:00                                            NaN  ...
# 2020-05-31 20:00:00     Состояние неба в общем не изменилось.  NaN  ...
#
#                                                                        Cl  \
# Местное время в Тюмени
# 2020-05-30 17:00:00     Кучевые средние или мощные или вместе с кучевы...
# 2020-05-30 20:00:00     Слоисто-кучевых, слоистых, кучевых или кучево-...
# 2020-05-31 14:00:00        Слоисто-кучевые, образовавшиеся не из кучевых.
# 2020-05-31 17:00:00        Слоисто-кучевые, образовавшиеся не из кучевых.
# 2020-05-31 20:00:00        Слоисто-кучевые, образовавшиеся не из кучевых.
#
#                              Nh                                 H  \
# Местное время в Тюмени
# 2020-05-30 17:00:00     20–30%.                         1000-1500
# 2020-05-30 20:00:00        40%.  2500 или более, или облаков нет.
# 2020-05-31 14:00:00        50%.                         1000-1500
# 2020-05-31 17:00:00        40%.                         1000-1500
# 2020-05-31 20:00:00     20–30%.                         1000-1500
#
#                                                                        Cm  \
# Местное время в Тюмени
# 2020-05-30 17:00:00     Высококучевых, высокослоистых или слоисто-дожд...
# 2020-05-30 20:00:00     Высококучевые просвечивающие, расположенные на...
# 2020-05-31 14:00:00     Высококучевые, просвечивающие или плотные в дв...
# 2020-05-31 17:00:00     Высококучевые, просвечивающие или плотные в дв...
# 2020-05-31 20:00:00       Высококучевые башенкообразные или хлопьевидные.
#
#                                                                        Ch  \
# Местное время в Тюмени
# 2020-05-30 17:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2020-05-30 20:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2020-05-31 14:00:00     Перистые когтевидные или нитевидные или первые...
# 2020-05-31 17:00:00     Перистых, перисто-кучевых или перисто-слоистых...
# 2020-05-31 20:00:00                                                   NaN
#
#                           VV   Td            RRR    tR  sss
# Местное время в Тюмени
# 2020-05-30 17:00:00     10.0  5.0            NaN   NaN  NaN
# 2020-05-30 20:00:00     10.0  6.9    Осадков нет  12.0  NaN
# 2020-05-31 14:00:00     10.0  4.4            NaN   NaN  NaN
# 2020-05-31 17:00:00     10.0  2.9            NaN   NaN  NaN
# 2020-05-31 20:00:00     10.0  5.0  Следы осадков  12.0  NaN
#
# [5 rows x 21 columns]

# %%
df12 = df_t.copy()
df12['datetime'] = df_t.index.to_pydatetime()
df12[['year','month','res_']] = df12['datetime'].astype(str).str.split('-', expand=True)
df12[['day', 'res_']] = df12['res_'].astype(str).str.split(' ', expand=True)
df12[['hour', 'min', 'sec']] = df12['res_'].astype(str).str.split(':', expand=True)
df12 = df12.drop(columns = ['res_', 'min', 'sec'])
df12[df12['hour'].astype(int).between(14, 20, inclusive=True)].tail(5)
# Out:
#                            T     Po      P   Pa     U  \
# Местное время в Тюмени
# 2021-05-11 17:00:00     22.4  759.8  768.7 -0.7  17.0
# 2021-05-11 20:00:00     19.8  759.9  768.9  0.1  21.0
# 2021-05-12 14:00:00     20.8  760.6  769.6 -0.3  28.0
# 2021-05-12 17:00:00     21.1  760.5  769.4 -0.1  26.0
# 2021-05-12 20:00:00     19.1  760.1  769.1 -0.4  32.0
#
#                                                           DD   Ff          N  \
# Местное время в Тюмени
# 2021-05-11 17:00:00                   Ветер, дующий с запада  1.0      100%.
# 2021-05-11 20:00:00                   Ветер, дующий с запада  1.0  70 – 80%.
# 2021-05-12 14:00:00                   Ветер, дующий с севера  3.0       40%.
# 2021-05-12 17:00:00     Ветер, дующий с северо-северо-запада  4.0       40%.
# 2021-05-12 20:00:00                         Штиль, безветрие  0.0  70 – 80%.
#
#                             WW  Tn  ...    VV   Td          RRR    tR  sss  \
# Местное время в Тюмени              ...
# 2021-05-11 17:00:00     Мгла.  NaN  ...   4.0 -4.1          NaN   NaN  NaN
# 2021-05-11 20:00:00     Мгла.  NaN  ...   4.0 -3.0  Осадков нет  12.0  NaN
# 2021-05-12 14:00:00            NaN  ...  10.0  1.7          NaN   NaN  NaN
# 2021-05-12 17:00:00            NaN  ...  10.0  0.6          NaN   NaN  NaN
# 2021-05-12 20:00:00            NaN  ...  10.0  2.1  Осадков нет  12.0  NaN
#
#                                   datetime  year  month day  hour
# Местное время в Тюмени
# 2021-05-11 17:00:00    2021-05-11 17:00:00  2021     05  11    17
# 2021-05-11 20:00:00    2021-05-11 20:00:00  2021     05  11    20
# 2021-05-12 14:00:00    2021-05-12 14:00:00  2021     05  12    14
# 2021-05-12 17:00:00    2021-05-12 17:00:00  2021     05  12    17
# 2021-05-12 20:00:00    2021-05-12 20:00:00  2021     05  12    20
#
# [5 rows x 26 columns]

# %%
# def custom_resampler(array_like):
#     return np.sum(array_like) / len(array_like)

# df_t['T'].resample('60min').apply(custom_resampler)
# df_t['T'].resample('60min').bfill()

# %%
def get_td(first_date_str, second_date_str):
   tdelta = datetime.datetime.strptime(first_date_str, "%Y-%m-%d") - datetime.datetime.strptime(second_date_str.date, "%Y-%m-%d")
   return tdelta.days

# %% [markdown]
# #### поиск периодов с низкой температурой

# %%
fltr = df_t.loc[df_t.index.hour.isin([5])].loc['2020-11':'2021-02']
fltr = fltr[fltr['T'] < -25]

# %%
fltr['datetime'] = fltr.index.to_pydatetime()
fltr['datetime'] = fltr['datetime'].dt.date
fltr['diff'] = (fltr['datetime'] - fltr.shift(1)['datetime'])
# fltr = fltr[fltr['diff'] == datetime.timedelta(days=1)]

# %%
fltr['inc4days'] = ((fltr['datetime'] - fltr.shift(1)['datetime'] == datetime.timedelta(days=1)) & (fltr['datetime'] - fltr.shift(2)['datetime'] == datetime.timedelta(days=2)) & (fltr['datetime'] - fltr.shift(3)['datetime'] == datetime.timedelta(days=3)))

# %%
def myf(x):
#     print(x)
    if (np.average(x) < -27):
        return True
    else:
        return False
n = 3
fltr['new_value'] = fltr.rolling(window = 3)['T'].apply(myf)[n-1::n]
fltr
# Out:
#                            T     Po      P   Pa     U  \
# Местное время в Тюмени
# 2020-12-25 05:00:00    -28.1  766.3  777.1  1.3  73.0
# 2020-12-30 05:00:00    -27.7  765.7  776.5  0.9  73.0
# 2020-12-31 05:00:00    -30.7  770.1  781.1  0.8  71.0
# 2021-01-01 05:00:00    -31.3  774.3  785.4  0.8  70.0
# 2021-01-02 05:00:00    -31.1  778.0  789.1  0.6  69.0
# 2021-01-03 05:00:00    -28.4  780.3  791.4  0.1  73.0
# 2021-01-07 05:00:00    -26.8  777.8  788.8 -0.5  76.0
# 2021-01-12 05:00:00    -25.1  759.6  770.2 -0.6  74.0
# 2021-01-13 05:00:00    -29.3  765.5  776.4  1.3  72.0
# 2021-01-14 05:00:00    -32.6  771.7  782.9  0.6  67.0
# 2021-01-15 05:00:00    -25.5  767.7  778.4 -1.3  75.0
# 2021-01-22 05:00:00    -27.9  749.2  759.8  0.6  73.0
# 2021-01-23 05:00:00    -31.7  762.5  773.5  1.9  70.0
# 2021-01-24 05:00:00    -35.1  769.3  780.6  0.2  64.0
# 2021-02-09 05:00:00    -26.7  740.3  750.7  1.4  68.0
# 2021-02-10 05:00:00    -27.8  754.5  765.1  1.9  72.0
# 2021-02-11 05:00:00    -31.5  763.1  774.1  0.4  70.0
# 2021-02-12 05:00:00    -29.6  763.7  774.6 -0.2  72.0
# 2021-02-19 05:00:00    -26.1  751.3  761.8  0.8  72.0
# 2021-02-20 05:00:00    -27.9  756.5  767.2 -0.4  75.0
# 2021-02-22 05:00:00    -29.5  757.6  768.4  0.1  74.0
# 2021-02-23 05:00:00    -27.7  759.6  770.4 -0.1  72.0
# 2021-02-24 05:00:00    -25.1  751.2  761.7 -1.7  71.0
# 2021-02-26 05:00:00    -30.7  760.6  771.5  0.3  71.0
# 2021-02-27 05:00:00    -25.6  759.7  770.4 -0.6  76.0
#
#                                                            DD   Ff  \
# Местное время в Тюмени
# 2020-12-25 05:00:00                    Ветер, дующий с севера  2.0
# 2020-12-30 05:00:00                    Ветер, дующий с запада  2.0
# 2020-12-31 05:00:00                    Ветер, дующий с запада  1.0
# 2021-01-01 05:00:00             Ветер, дующий с северо-запада  1.0
# 2021-01-02 05:00:00       Ветер, дующий с востоко-юго-востока  2.0
# 2021-01-03 05:00:00       Ветер, дующий с востоко-юго-востока  3.0
# 2021-01-07 05:00:00       Ветер, дующий с востоко-юго-востока  2.0
# 2021-01-12 05:00:00            Ветер, дующий с северо-востока  3.0
# 2021-01-13 05:00:00      Ветер, дующий с северо-северо-запада  2.0
# 2021-01-14 05:00:00                          Штиль, безветрие  0.0
# 2021-01-15 05:00:00               Ветер, дующий с юго-востока  2.0
# 2021-01-22 05:00:00                Ветер, дующий с юго-запада  1.0
# 2021-01-23 05:00:00      Ветер, дующий с северо-северо-запада  2.0
# 2021-01-24 05:00:00       Ветер, дующий с востоко-юго-востока  1.0
# 2021-02-09 05:00:00         Ветер, дующий с западо-юго-запада  3.0
# 2021-02-10 05:00:00         Ветер, дующий с западо-юго-запада  3.0
# 2021-02-11 05:00:00                          Штиль, безветрие  0.0
# 2021-02-12 05:00:00                          Штиль, безветрие  0.0
# 2021-02-19 05:00:00             Ветер, дующий с северо-запада  3.0
# 2021-02-20 05:00:00                   Ветер, дующий с востока  1.0
# 2021-02-22 05:00:00                          Штиль, безветрие  0.0
# 2021-02-23 05:00:00     Ветер, дующий с северо-северо-востока  2.0
# 2021-02-24 05:00:00                    Ветер, дующий с севера  5.0
# 2021-02-26 05:00:00                          Штиль, безветрие  0.0
# 2021-02-27 05:00:00               Ветер, дующий с юго-востока  2.0
#
#                                    N  \
# Местное время в Тюмени
# 2020-12-25 05:00:00          20–30%.
# 2020-12-30 05:00:00            100%.
# 2020-12-31 05:00:00          20–30%.
# 2021-01-01 05:00:00     Облаков нет.
# 2021-01-02 05:00:00     Облаков нет.
# 2021-01-03 05:00:00             40%.
# 2021-01-07 05:00:00     Облаков нет.
# 2021-01-12 05:00:00            100%.
# 2021-01-13 05:00:00            100%.
# 2021-01-14 05:00:00     Облаков нет.
# 2021-01-15 05:00:00            100%.
# 2021-01-22 05:00:00     Облаков нет.
# 2021-01-23 05:00:00     Облаков нет.
# 2021-01-24 05:00:00     Облаков нет.
# 2021-02-09 05:00:00             60%.
# 2021-02-10 05:00:00     Облаков нет.
# 2021-02-11 05:00:00     Облаков нет.
# 2021-02-12 05:00:00              NaN
# 2021-02-19 05:00:00              NaN
# 2021-02-20 05:00:00     Облаков нет.
# 2021-02-22 05:00:00          20–30%.
# 2021-02-23 05:00:00            100%.
# 2021-02-24 05:00:00            100%.
# 2021-02-26 05:00:00          20–30%.
# 2021-02-27 05:00:00          20–30%.
#
#                                                                        WW  Tn  \
# Местное время в Тюмени
# 2020-12-25 05:00:00                                                       NaN
# 2020-12-30 05:00:00              Алмазная пыль (с туманом или без него).  NaN
# 2020-12-31 05:00:00       Диаметр изморозевого отложения составляет 2 мм. NaN
# 2021-01-01 05:00:00       Диаметр изморозевого отложения составляет 2 мм. NaN
# 2021-01-02 05:00:00       Диаметр изморозевого отложения составляет 2 мм. NaN
# 2021-01-03 05:00:00       Диаметр изморозевого отложения составляет 2 мм. NaN
# 2021-01-07 05:00:00                                                       NaN
# 2021-01-12 05:00:00     Слабый или умеренный поземок в целом низкий (н... NaN
# 2021-01-13 05:00:00                                                       NaN
# 2021-01-14 05:00:00                                                       NaN
# 2021-01-15 05:00:00                                                       NaN
# 2021-01-22 05:00:00                Состояние неба в общем не изменилось.  NaN
# 2021-01-23 05:00:00                Состояние неба в общем не изменилось.  NaN
# 2021-01-24 05:00:00                                                       NaN
# 2021-02-09 05:00:00                Состояние неба в общем не изменилось.  NaN
# 2021-02-10 05:00:00                Состояние неба в общем не изменилось.  NaN
# 2021-02-11 05:00:00                                                       NaN
# 2021-02-12 05:00:00                                                       NaN
# 2021-02-19 05:00:00                                                       NaN
# 2021-02-20 05:00:00                                                       NaN
# 2021-02-22 05:00:00                                                       NaN
# 2021-02-23 05:00:00           Снег непрерывный слабый в срок наблюдения.  NaN
# 2021-02-24 05:00:00     Слабая или умеренная снежная низовая метель в ... NaN
# 2021-02-26 05:00:00                                                       NaN
# 2021-02-27 05:00:00                                                       NaN
#
#                         ...  \
# Местное время в Тюмени  ...
# 2020-12-25 05:00:00     ...
# 2020-12-30 05:00:00     ...
# 2020-12-31 05:00:00     ...
# 2021-01-01 05:00:00     ...
# 2021-01-02 05:00:00     ...
# 2021-01-03 05:00:00     ...
# 2021-01-07 05:00:00     ...
# 2021-01-12 05:00:00     ...
# 2021-01-13 05:00:00     ...
# 2021-01-14 05:00:00     ...
# 2021-01-15 05:00:00     ...
# 2021-01-22 05:00:00     ...
# 2021-01-23 05:00:00     ...
# 2021-01-24 05:00:00     ...
# 2021-02-09 05:00:00     ...
# 2021-02-10 05:00:00     ...
# 2021-02-11 05:00:00     ...
# 2021-02-12 05:00:00     ...
# 2021-02-19 05:00:00     ...
# 2021-02-20 05:00:00     ...
# 2021-02-22 05:00:00     ...
# 2021-02-23 05:00:00     ...
# 2021-02-24 05:00:00     ...
# 2021-02-26 05:00:00     ...
# 2021-02-27 05:00:00     ...
#
#                                                                        Ch  \
# Местное время в Тюмени
# 2020-12-25 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2020-12-30 05:00:00     Перисто-кучевые одни или перисто-кучевые, сопр...
# 2020-12-31 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-01-01 05:00:00                                                   NaN
# 2021-01-02 05:00:00                                                   NaN
# 2021-01-03 05:00:00     Перистых, перисто-кучевых или перисто-слоистых...
# 2021-01-07 05:00:00                                                   NaN
# 2021-01-12 05:00:00                                                   NaN
# 2021-01-13 05:00:00                                                   NaN
# 2021-01-14 05:00:00                                                   NaN
# 2021-01-15 05:00:00                                                   NaN
# 2021-01-22 05:00:00                                                   NaN
# 2021-01-23 05:00:00                                                   NaN
# 2021-01-24 05:00:00                                                   NaN
# 2021-02-09 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-02-10 05:00:00                                                   NaN
# 2021-02-11 05:00:00                                                   NaN
# 2021-02-12 05:00:00                                                   NaN
# 2021-02-19 05:00:00                                                   NaN
# 2021-02-20 05:00:00                                                   NaN
# 2021-02-22 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-02-23 05:00:00                                                   NaN
# 2021-02-24 05:00:00                                                   NaN
# 2021-02-26 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
# 2021-02-27 05:00:00     Перистые нитевидные, иногда когтевидные, не ра...
#
#                           VV    Td  RRR  tR  sss    datetime    diff inc4days  \
# Местное время в Тюмени
# 2020-12-25 05:00:00     10.0 -31.4  NaN NaN  NaN  2020-12-25     NaT    False
# 2020-12-30 05:00:00     10.0 -31.1  NaN NaN  NaN  2020-12-30  5 days    False
# 2020-12-31 05:00:00     10.0 -34.3  NaN NaN  NaN  2020-12-31  1 days    False
# 2021-01-01 05:00:00     10.0 -34.9  NaN NaN  NaN  2021-01-01  1 days    False
# 2021-01-02 05:00:00     10.0 -34.9  NaN NaN  NaN  2021-01-02  1 days     True
# 2021-01-03 05:00:00     10.0 -31.8  NaN NaN  NaN  2021-01-03  1 days     True
# 2021-01-07 05:00:00     10.0 -29.8  NaN NaN  NaN  2021-01-07  4 days    False
# 2021-01-12 05:00:00     10.0 -28.4  NaN NaN  NaN  2021-01-12  5 days    False
# 2021-01-13 05:00:00     10.0 -32.8  NaN NaN  NaN  2021-01-13  1 days    False
# 2021-01-14 05:00:00     10.0 -36.6  NaN NaN  NaN  2021-01-14  1 days    False
# 2021-01-15 05:00:00     10.0 -28.6  NaN NaN  NaN  2021-01-15  1 days     True
# 2021-01-22 05:00:00     10.0 -31.2  NaN NaN  NaN  2021-01-22  7 days    False
# 2021-01-23 05:00:00     10.0 -35.4  NaN NaN  NaN  2021-01-23  1 days    False
# 2021-01-24 05:00:00     10.0 -39.4  NaN NaN  NaN  2021-01-24  1 days    False
# 2021-02-09 05:00:00     10.0 -30.8  NaN NaN  NaN  2021-02-09 16 days    False
# 2021-02-10 05:00:00     10.0 -31.3  NaN NaN  NaN  2021-02-10  1 days    False
# 2021-02-11 05:00:00     10.0 -35.2  NaN NaN  NaN  2021-02-11  1 days    False
# 2021-02-12 05:00:00      NaN -33.0  NaN NaN  NaN  2021-02-12  1 days     True
# 2021-02-19 05:00:00      NaN -29.7  NaN NaN  NaN  2021-02-19  7 days    False
# 2021-02-20 05:00:00     10.0 -31.0  NaN NaN  NaN  2021-02-20  1 days    False
# 2021-02-22 05:00:00     10.0 -32.7  NaN NaN  NaN  2021-02-22  2 days    False
# 2021-02-23 05:00:00      4.0 -31.2  NaN NaN  NaN  2021-02-23  1 days    False
# 2021-02-24 05:00:00      4.0 -28.9  NaN NaN  NaN  2021-02-24  1 days    False
# 2021-02-26 05:00:00     10.0 -34.3  NaN NaN  NaN  2021-02-26  2 days    False
# 2021-02-27 05:00:00     10.0 -28.6  NaN NaN  NaN  2021-02-27  1 days    False
#
#                         new_value
# Местное время в Тюмени
# 2020-12-25 05:00:00           NaN
# 2020-12-30 05:00:00           NaN
# 2020-12-31 05:00:00           1.0
# 2021-01-01 05:00:00           1.0
# 2021-01-02 05:00:00           1.0
# 2021-01-03 05:00:00           1.0
# 2021-01-07 05:00:00           1.0
# 2021-01-12 05:00:00           0.0
# 2021-01-13 05:00:00           1.0
# 2021-01-14 05:00:00           1.0
# 2021-01-15 05:00:00           1.0
# 2021-01-22 05:00:00           1.0
# 2021-01-23 05:00:00           1.0
# 2021-01-24 05:00:00           1.0
# 2021-02-09 05:00:00           1.0
# 2021-02-10 05:00:00           1.0
# 2021-02-11 05:00:00           1.0
# 2021-02-12 05:00:00           1.0
# 2021-02-19 05:00:00           1.0
# 2021-02-20 05:00:00           1.0
# 2021-02-22 05:00:00           1.0
# 2021-02-23 05:00:00           1.0
# 2021-02-24 05:00:00           1.0
# 2021-02-26 05:00:00           1.0
# 2021-02-27 05:00:00           1.0
#
# [25 rows x 25 columns]
