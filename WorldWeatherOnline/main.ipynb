# %%
from wwo_hist import retrieve_hist_data
import os
#os.chdir(".\YOUR_PATH")
os.chdir("B:/Projects/CourseWork/WorldWeatherOnline/data")

# %%
#2008-06-31

# %%
#frequency = 3
frequency = 1
#start_date = '11-DEC-2018'
#end_date = '11-MAR-2019'
start_date = '01-JUL-2008'
end_date = '23-NOV-2019'
api_key = '1ab13535d00f47fc889142739192111'
#location_list = ['singapore','california']
#location_list = ['novosibirsk', 'tomsk', 'chita']
location_list = ['Tallinn']

# %%
hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Tallinn
#
#
# Currently retrieving data for Tallinn: from 2008-07-01 to 2008-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.585180
# Currently retrieving data for Tallinn: from 2008-08-01 to 2008-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.916824
# Currently retrieving data for Tallinn: from 2008-09-01 to 2008-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.979192
# Currently retrieving data for Tallinn: from 2008-10-01 to 2008-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.454693
# Currently retrieving data for Tallinn: from 2008-11-01 to 2008-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:11.653553
# Currently retrieving data for Tallinn: from 2008-12-01 to 2008-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.695453
# Currently retrieving data for Tallinn: from 2009-01-01 to 2009-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:15.734269
# Currently retrieving data for Tallinn: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:17.575422
# Currently retrieving data for Tallinn: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.504668
# Currently retrieving data for Tallinn: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:21.441933
# Currently retrieving data for Tallinn: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:23.446481
# Currently retrieving data for Tallinn: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:25.483080
# Currently retrieving data for Tallinn: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:28.290316
# Currently retrieving data for Tallinn: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:30.318390
# Currently retrieving data for Tallinn: from 2009-09-01 to 2009-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:32.286940
# Currently retrieving data for Tallinn: from 2009-10-01 to 2009-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:34.311114
# Currently retrieving data for Tallinn: from 2009-11-01 to 2009-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.463407
# Currently retrieving data for Tallinn: from 2009-12-01 to 2009-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:38.774239
# Currently retrieving data for Tallinn: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:40.863330
# Currently retrieving data for Tallinn: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:42.882992
# Currently retrieving data for Tallinn: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:45.059197
# Currently retrieving data for Tallinn: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:47.167112
# Currently retrieving data for Tallinn: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:49.257929
# Currently retrieving data for Tallinn: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:51.269028
# Currently retrieving data for Tallinn: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:53.507165
# Currently retrieving data for Tallinn: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:55.548635
# Currently retrieving data for Tallinn: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:57.593217
# Currently retrieving data for Tallinn: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:59.789215
# Currently retrieving data for Tallinn: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:01.985389
# Currently retrieving data for Tallinn: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:04.035019
# Currently retrieving data for Tallinn: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.107981
# Currently retrieving data for Tallinn: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:07.982061
# Currently retrieving data for Tallinn: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:10.001302
# Currently retrieving data for Tallinn: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:12.132891
# Currently retrieving data for Tallinn: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.387844
# Currently retrieving data for Tallinn: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:16.187224
# Currently retrieving data for Tallinn: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:18.001103
# Currently retrieving data for Tallinn: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:19.784021
# Currently retrieving data for Tallinn: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:21.799201
# Currently retrieving data for Tallinn: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:24.054393
# Currently retrieving data for Tallinn: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:26.134163
# Currently retrieving data for Tallinn: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:28.147085
# Currently retrieving data for Tallinn: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:30.315512
# Currently retrieving data for Tallinn: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:32.248010
# Currently retrieving data for Tallinn: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:34.337211
# Currently retrieving data for Tallinn: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:36.357217
# Currently retrieving data for Tallinn: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:38.457150
# Currently retrieving data for Tallinn: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:40.483013
# Currently retrieving data for Tallinn: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:42.501659
# Currently retrieving data for Tallinn: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:44.594213
# Currently retrieving data for Tallinn: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:46.704598
# Currently retrieving data for Tallinn: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:49.553834
# Currently retrieving data for Tallinn: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:51.615151
# Currently retrieving data for Tallinn: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:53.673051
# Currently retrieving data for Tallinn: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:56.064574
# Currently retrieving data for Tallinn: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:58.231465
# Currently retrieving data for Tallinn: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:02.304246
# Currently retrieving data for Tallinn: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:05.252155
# Currently retrieving data for Tallinn: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:07.761416
# Currently retrieving data for Tallinn: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:09.992816
# Currently retrieving data for Tallinn: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:12.235781
# Currently retrieving data for Tallinn: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:14.349254
# Currently retrieving data for Tallinn: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:16.465059
# Currently retrieving data for Tallinn: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:18.530312
# Currently retrieving data for Tallinn: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:20.658444
# Currently retrieving data for Tallinn: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:22.783048
# Currently retrieving data for Tallinn: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:24.997065
# Currently retrieving data for Tallinn: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:27.326727
# Currently retrieving data for Tallinn: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:29.559371
# Currently retrieving data for Tallinn: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:31.617192
# Currently retrieving data for Tallinn: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:35.130901
# Currently retrieving data for Tallinn: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:37.103666
# Currently retrieving data for Tallinn: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:39.392443
# Currently retrieving data for Tallinn: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:41.487846
# Currently retrieving data for Tallinn: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:43.619831
# Currently retrieving data for Tallinn: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:45.688018
# Currently retrieving data for Tallinn: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:47.830077
# Currently retrieving data for Tallinn: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:50.051882
# Currently retrieving data for Tallinn: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:52.153014
# Currently retrieving data for Tallinn: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:53.767548
# Currently retrieving data for Tallinn: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:55.364706
# Currently retrieving data for Tallinn: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:56.749422
# Currently retrieving data for Tallinn: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:58.191642
# Currently retrieving data for Tallinn: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:59.624669
# Currently retrieving data for Tallinn: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:02.059876
# Currently retrieving data for Tallinn: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:03.528173
# Currently retrieving data for Tallinn: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:04.851356
# Currently retrieving data for Tallinn: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:06.219546
# Currently retrieving data for Tallinn: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:07.584932
# Currently retrieving data for Tallinn: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:08.928807
# Currently retrieving data for Tallinn: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:10.306861
# Currently retrieving data for Tallinn: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:03:11.598935
# Currently retrieving data for Tallinn: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:12.983889
# Currently retrieving data for Tallinn: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:14.415420
# Currently retrieving data for Tallinn: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:15.778400
# Currently retrieving data for Tallinn: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:17.202656
# Currently retrieving data for Tallinn: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:18.659476
# Currently retrieving data for Tallinn: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:20.119272
# Currently retrieving data for Tallinn: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:21.470422
# Currently retrieving data for Tallinn: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:22.942196
# Currently retrieving data for Tallinn: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:24.367229
# Currently retrieving data for Tallinn: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:25.960949
# Currently retrieving data for Tallinn: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:27.696411
# Currently retrieving data for Tallinn: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:29.190098
# Currently retrieving data for Tallinn: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:30.662957
# Currently retrieving data for Tallinn: from 2017-04-01 to 2017-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:32.501750
# Currently retrieving data for Tallinn: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:34.415985
# Currently retrieving data for Tallinn: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:36.011145
# Currently retrieving data for Tallinn: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:37.419929
# Currently retrieving data for Tallinn: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:39.069112
# Currently retrieving data for Tallinn: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:40.670141
# Currently retrieving data for Tallinn: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:42.411596
# Currently retrieving data for Tallinn: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:43.946185
# Currently retrieving data for Tallinn: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:45.401808
# Currently retrieving data for Tallinn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:47.026209
# Currently retrieving data for Tallinn: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:48.481497
# Currently retrieving data for Tallinn: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:50.074129
# Currently retrieving data for Tallinn: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:51.734881
# Currently retrieving data for Tallinn: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:53.252921
# Currently retrieving data for Tallinn: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:54.784533
# Currently retrieving data for Tallinn: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:56.386621
# Currently retrieving data for Tallinn: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:57.956211
# Currently retrieving data for Tallinn: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:59.410275
# Currently retrieving data for Tallinn: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:01.030387
# Currently retrieving data for Tallinn: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:02.544254
# Currently retrieving data for Tallinn: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:04.084475
# Currently retrieving data for Tallinn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:04:05.723798
# Currently retrieving data for Tallinn: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:04:07.263619
# Currently retrieving data for Tallinn: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:08.852364
# Currently retrieving data for Tallinn: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:10.444310
# Currently retrieving data for Tallinn: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:13.723384
# Currently retrieving data for Tallinn: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:15.481980
# Currently retrieving data for Tallinn: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:17.792275
# Currently retrieving data for Tallinn: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:19.210584
# Currently retrieving data for Tallinn: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:21.160864
# Currently retrieving data for Tallinn: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:27.504091
# Currently retrieving data for Tallinn: from 2019-11-01 to 2019-11-23
# Time elapsed (hh:mm:ss.ms) 0:04:29.530335
#
#
# export Tallinn completed!

# %%
# Out:
# B:\Projects\CourseWork\WorldWeatherOnline\data
