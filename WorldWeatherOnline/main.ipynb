# %%
from wwo_hist import retrieve_hist_data
import os
#os.chdir(".\YOUR_PATH")
os.chdir("B:/Projects/CourseWork/coursework/WorldWeatherOnline/data")

# %%
#2008-06-31

# %%
#frequency = 3
frequency = 1
#start_date = '11-DEC-2018'
#end_date = '11-MAR-2019'
start_date = '01-JUL-2008'
end_date = '23-NOV-2019'
api_key = '1ab13535d00f47fc889142739192111'
#location_list = ['singapore','california']
#location_list = ['novosibirsk', 'tomsk', 'chita']
location_list = ['Oslo','Stockholm','Kuusamo']

# %%
hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Oslo
#
#
# Currently retrieving data for Oslo: from 2008-07-01 to 2008-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.302208
# Currently retrieving data for Oslo: from 2008-08-01 to 2008-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.392623
# Currently retrieving data for Oslo: from 2008-09-01 to 2008-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.021810
# Currently retrieving data for Oslo: from 2008-10-01 to 2008-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.706854
# Currently retrieving data for Oslo: from 2008-11-01 to 2008-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.162222
# Currently retrieving data for Oslo: from 2008-12-01 to 2008-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.768527
# Currently retrieving data for Oslo: from 2009-01-01 to 2009-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.067586
# Currently retrieving data for Oslo: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:14.378027
# ...

# %%
# Out:
# B:\Projects\CourseWork\WorldWeatherOnline\data
