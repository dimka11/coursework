# %%
#parse single html
import os
os.chdir("B:/Projects/CourseWork/coursework/HTMLCSV/ogimet/data")

from bs4 import BeautifulSoup
soup = BeautifulSoup(open("1999/101999.html", 'rb'), "lxml")
soup = soup.select('body > table> tr:nth-child(2) > td:nth-child(2) > table:nth-child(2) > thead')[0]

#one row

date = soup.select('tr:nth-child(2) > td:nth-child(1) > a')[0].string
time = soup.select('tr:nth-child(2) > td:nth-child(2) > a')[0].string
temp = soup.select('tr:nth-child(2) > td:nth-child(3) > font')[0].string
temp_d = soup.select('tr:nth-child(2) > td:nth-child(4) > font')[0].string
Tmax = soup.select('tr:nth-child(2) > td:nth-child(5)')[0].string
Tmin = soup.select('tr:nth-child(2) > td:nth-child(6)')[0].string
ddd = soup.select('tr:nth-child(2) > td:nth-child(7) > font')[0].string
ff_kmh = soup.select('tr:nth-child(2) > td:nth-child(8) > font')[0].string
Gust_kmh = soup.select('tr:nth-child(2) > td:nth-child(9)')[0].string
P0_hPa = soup.select('tr:nth-child(2) > td:nth-child(10) > font')[0].string
P_sea_hPa = soup.select('tr:nth-child(2) > td:nth-child(11) > font')[0].string
P_Tnd = soup.select('tr:nth-child(2) > td:nth-child(12) > font')[0].string
P_rec = soup.select('tr:nth-child(2) > td:nth-child(13)')[0].string
N_t = soup.select('tr:nth-child(2) > td:nth-child(14) > font')[0].string
N_h = soup.select('tr:nth-child(2) > td:nth-child(15) > font')[0].string
H_Km = soup.select('tr:nth-child(2) > td:nth-child(16) > font')[0].string
Inso_D_1 = soup.select('tr:nth-child(2) > td:nth-child(17)')[0].string
Vis_km = soup.select('tr:nth-child(2) > td:nth-child(18) > font')[0].string
WW = soup.select('tr:nth-child(2) > td:nth-child(19) > img')[0]['alt']
W1 = soup.select('tr:nth-child(2) > td:nth-child(20) > img')[0]['alt']
W2 = soup.select('tr:nth-child(2) > td:nth-child(21) > img')[0]['alt']

# %%
# print

print(date, end = ' ')
print(time, end = ' ')
print(temp, end = ' ')
print(temp_d, end = ' ')
print(Tmax, end = ' ')
print(Tmin, end = ' ')
print(ddd, end = ' ')
print(ff_kmh, end = ' ')
print(Gust_kmh, end = ' ')
print(P0_hPa, end = ' ')
print(P_sea_hPa, end = ' ')
print(P_Tnd, end = ' ')
print(P_rec, end = ' ')
print(N_t, end = ' ')
print(N_h, end = ' ')
print(H_Km, end = ' ')
print(Inso_D_1, end = ' ')
print(Vis_km)
print(WW, end = ' ')
print(W1, end = ' ')
print(W2)
print ('---------------')
# Out:
# 10/01/1999 12:00 14.0 11.0 ----- ----- CAL 0.0 ---- 1003.1 1017.8 +0.6 ---- 8 6 0.3 --- 20.0
# Rain shower. Daylight. At 10/01/1999 12:00 UTC  Rain shower. Daylight. Before 07 UTC  Drizzle. Daylight. Before 10 UTC
# ---------------

# %%
soup = BeautifulSoup(open("2002/102002.html", 'rb'), "lxml")
soup = soup.select('body > table> tr:nth-child(2) > td:nth-child(2) > table:nth-child(2) > thead')[0]

for i, tr in enumerate(soup.findAll("tr")):
    if i == 0:
        continue
    date = tr.select('td:nth-child(1) > a')[0].string
    time = tr.select('td:nth-child(2) > a')[0].string
    temp = tr.select('td:nth-child(3) > font')[0].string
    print(date, end = ' ')
    print(time, end = ' ')
    print(temp)
# Out:
# 10/01/2002 12:00 9.4
# 10/01/2002 09:00 8.3
# 10/01/2002 06:00 6.5
# 10/01/2002 03:00 4.0
# 10/01/2002 00:00 3.4
# 09/30/2002 21:00 4.5
# 09/30/2002 18:00 6.5
# 09/30/2002 15:00 8.4
# 09/30/2002 12:00 12.3
# 09/30/2002 09:00 16.4
# 09/30/2002 06:00 16.2
# 09/30/2002 03:00 14.2
# 09/30/2002 00:00 11.8
# 09/29/2002 21:00 11.2
# 09/29/2002 18:00 11.3
# 09/29/2002 15:00 9.1
# 09/29/2002 12:00 6.4
# 09/29/2002 09:00 6.6
# 09/29/2002 06:00 5.0
# 09/29/2002 03:00 2.5
# 09/29/2002 00:00 1.1
# 09/28/2002 21:00 1.4
# 09/28/2002 18:00 4.8
# 09/28/2002 15:00 8.6
# 09/28/2002 12:00 14.2
# 09/28/2002 09:00 14.2
# 09/28/2002 06:00 10.3
# 09/28/2002 03:00 6.9
# 09/28/2002 00:00 4.9
# 09/27/2002 21:00 7.4
# 09/27/2002 18:00 8.0
# 09/27/2002 15:00 10.0
# 09/27/2002 12:00 13.4
# 09/27/2002 09:00 14.4
# 09/27/2002 06:00 13.1
# 09/27/2002 03:00 3.6
# 09/27/2002 00:00 0.8
# 09/26/2002 21:00 1.4
# 09/26/2002 18:00 3.9
# 09/26/2002 15:00 6.1
# 09/26/2002 12:00 12.0
# 09/26/2002 09:00 12.8
# 09/26/2002 06:00 10.0
# 09/26/2002 03:00 5.7
# 09/26/2002 00:00 5.3
# 09/25/2002 21:00 7.3
# 09/25/2002 18:00 10.1
# 09/25/2002 15:00 13.1
# 09/25/2002 12:00 17.1
# 09/25/2002 09:00 22.6
# 09/25/2002 06:00 19.9
# 09/25/2002 03:00 14.5
# 09/25/2002 00:00 11.0
# 09/24/2002 21:00 10.4
# 09/24/2002 18:00 11.0
# 09/24/2002 15:00 10.8
# 09/24/2002 12:00 11.2
# 09/24/2002 09:00 10.6
# 09/24/2002 06:00 7.6
# 09/24/2002 03:00 6.0
# 09/24/2002 00:00 6.6
# 09/23/2002 21:00 5.9
# 09/23/2002 18:00 5.7
# 09/23/2002 15:00 5.5
# 09/23/2002 12:00 11.1
# 09/23/2002 09:00 11.1
# 09/23/2002 06:00 10.1
# 09/23/2002 03:00 7.4
# 09/23/2002 00:00 7.1
# 09/22/2002 21:00 7.7
# 09/01/2002 21:00 13.8
# 09/01/2002 18:00 15.2
# 09/01/2002 15:00 18.5
# 09/01/2002 12:00 22.1
# 09/01/2002 09:00 22.0
# 09/01/2002 06:00 18.3
# 09/01/2002 03:00 12.8
# 09/01/2002 00:00 8.6
# 08/31/2002 21:00 9.9
# 08/31/2002 18:00 11.4
# 08/31/2002 15:00 13.9
# 08/31/2002 12:00 18.2

# %%
# reversed and append to dataframe
# append to dataframe
import pandas as pd
data = []
col_names = ['date', 'time', 'temp']


soup = BeautifulSoup(open("2002/102002.html", 'rb'), "lxml")
soup = soup.select('body > table> tr:nth-child(2) > td:nth-child(2) > table:nth-child(2) > thead')[0]

for i, tr in enumerate(reversed(soup.findAll("tr"))):
    if i == len(soup.findAll("tr")) - 1:
        continue
    date = str(tr.select('td:nth-child(1) > a')[0].string)
    time = str(tr.select('td:nth-child(2) > a')[0].string)
    temp = str(tr.select('td:nth-child(3) > font')[0].string)
#     print(date, end = ' ')
#     print(time, end = ' ')
#     print(temp)
    data.append({'date': date, 'time': time, 'temp': temp})
    
df = pd.DataFrame(data, columns = col_names)
df.head(20)
# Out:
#           date   time  temp
# 0   08/31/2002  12:00  18.2
# 1   08/31/2002  15:00  13.9
# 2   08/31/2002  18:00  11.4
# 3   08/31/2002  21:00   9.9
# 4   09/01/2002  00:00   8.6
# 5   09/01/2002  03:00  12.8
# 6   09/01/2002  06:00  18.3
# 7   09/01/2002  09:00  22.0
# 8   09/01/2002  12:00  22.1
# 9   09/01/2002  15:00  18.5
# 10  09/01/2002  18:00  15.2
# 11  09/01/2002  21:00  13.8
# 12  09/02/2002  00:00  12.1
# 13  09/02/2002  03:00  20.1
# 14  09/02/2002  06:00  22.1
# 15  09/02/2002  09:00  22.1
# 16  09/02/2002  12:00  22.2
# 17  09/02/2002  15:00  19.0
# 18  09/02/2002  18:00  17.6
# 19  09/02/2002  21:00  17.0

# %%
# station:
soup = BeautifulSoup(open("2002/102002.html", 'rb'), "lxml")
code = soup.select('body > table > tr:nth-child(2) > td:nth-child(2) > table:nth-child(1) > tr > td > h3 > font')[0]
title = soup.select('body > table > tr:nth-child(2) > td:nth-child(2) > table:nth-child(1) > tr > td > h3')[0]
lat = soup.select('body > table > tr:nth-child(2) > td:nth-child(2) > table:nth-child(1) > tr > td > h4 > font:nth-child(1)')[0]
lon = soup.select('body > table > tr:nth-child(2) > td:nth-child(2) > table:nth-child(1) > tr > td > h4 > font:nth-child(2)')[0]
alt = soup.select('body > table > tr:nth-child(2) > td:nth-child(2) > table:nth-child(1) > tr > td > h4 > font:nth-child(3)')[0]
print(code.string)
print(title.string)
print(lat.string)
print(lon.string)
print(alt.string)
# Out:
# 28698
# None
# 55-01-00N
# 073-23-00E
# 122

# %%
# all files

# %%
# load

# %%
# analysis
